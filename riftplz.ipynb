# %% [markdown]
# rift plz

# %%
# %%bash
#  wget --limit-rate=200k --no-clobber --convert-links --random-wait -r -p -E -e robots=off -U mozilla http://events.riftpluz.com/
# Out:
# Both --no-clobber and --convert-links were specified,only --convert-links will be used.
# --2014-08-14 11:46:03--  http://events.riftpluz.com/
# Resolving events.riftpluz.com (events.riftpluz.com)... 37.187.41.35, 2001:41d0:52:100::d16
# Connecting to events.riftpluz.com (events.riftpluz.com)|37.187.41.35|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: `events.riftpluz.com/index.html'
#
#      0K .......                                                17.7M=0s
#
# 2014-08-14 11:46:03 (17.7 MB/s) - `events.riftpluz.com/index.html' saved [7659]
#
# --2014-08-14 11:46:03--  http://events.riftpluz.com/css/11e58cd.css
# Reusing existing connection to events.riftpluz.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 122864 (120K) [text/css]
# Saving to: `events.riftpluz.com/css/11e58cd.css'
#
#      0K .......... .......... .......... .......... .......... 41%  216K 0s
# ...

# %%
import beautifulsoup
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 766, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 249, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python2.7/inspect.py", line 1043, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/usr/lib/python2.7/inspect.py", line 1003, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/usr/lib/python2.7/inspect.py", line 483, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python2.7/inspect.py", line 467, in getabsfile
# ...

# %%
print 'hello'
# Out:
# hello

# %%
import random

# %%
import bs4

# %%
bs4.BeautifulSoup.
