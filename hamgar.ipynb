# %%
import requests
from bs4 import BeautifulSoup

# %%
hamgar = requests.get('http://www.hamiltongardensartsfestival.co.nz/home/')

# %%
data = BeautifulSoup(hamgar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-7a865dd905c0> in <module>()
# ----> 1 data = BeautifulSoup(hamgar)
#
# /usr/lib/python2.7/site-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, **kwargs)
#     160         if hasattr(markup, 'read'):        # It's a file-type object.
#     161             markup = markup.read()
# --> 162         elif len(markup) <= 256:
#     163             # Print out warnings for a couple beginner problems
#     164             # involving passing non-markup to Beautiful Soup.
#
# TypeError: object of type 'Response' has no len()

# %%
def fileurl(urlsav):
    hamgar = requests.get(urlsav)

# %%
fileurl('http://www.hamiltongardensartsfestival.co.nz/home/')
# Out:
# <Response [200]>

# %%
print hamgar

savFile = open('hamgarden','w')
# Out:
# <Response [200]>

# %%
for d in hamgar:
    print d
    savFile.write(d)
# Out:
# <!doctype html>
# <!--[if lt IE 7]><html class="ie ie6" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:f
# b="http://www.facebook.com/2008/fbml"><![endif]-->
# <!--[if IE 7]><html class="ie ie7" xmlns="http://www.w3.org/1999/xhtml" xmln
# s:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><![endif]-->
# <!--[if IE 8]><html class="ie ie8" xmlns="ht
# tp://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><![endif]-->
# <!--[if gte
# IE 9]><!--><html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml">
# <!--<![endif]-->
# <head>
# <!--meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scala
# ble=false;"-->
# <meta http-equiv="content-type" content="text/html;charset=utf-8" />
# <!--META http-equiv="imagetoolbar" content
# ="no" /-->
# ...

# %%
print data
# Out:
# <html><body><p>pt')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#
# </p></body>
# </html>

# %%
openham = open('hamgarden', 'r')

# %%
hamdet = openham.readlines()

# %%
print haminfo
# Out:
# []
